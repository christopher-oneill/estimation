# %%
import os
from dotenv import load_dotenv
import numpy as np
import h5py


# 1. Environment Setup
load_dotenv()
base_dir = os.getenv("BASE_DIR")

data_dir = base_dir+"/data/DNS_CC_Re150_Mazi/"

import sys
sys.path.append(base_dir) # appends the repository to the path, importable as a python module

irregular_dataset = data_dir+"dns_complete_2d.h5"
irregular_dataset_file = h5py.File(irregular_dataset)
print(irregular_dataset_file.keys())
# Out:
# <KeysViewHDF5 ['grads', 'p', 'time', 'ux', 'uy', 'xy']>
